# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat
from scipy.stats import gaussian_kde
import pandas as pd
from sklearn.model_selection import train_test_split
from joblib import dump
from joblib import load
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import load_model
import tensorflow as tf
from tensorflow.keras import Input
from sklearn.metrics import r2_score,mean_absolute_error
import time
import sys
# Out:
# WARNING:tensorflow:From c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
col_names = ['lon', 'lat', 'lai_hv', 'wind',
          'temperature', 'rain', 'pressure',
          'radiation', 'biomass']
mydir = './good_data/'
datadir = './finaldata/'
lai = np.load(mydir+"lai_hv_interp_congo_025.npy")
wind = np.load(mydir+"wind_interp_congo_025.npy")
temp = np.load(mydir+"temperature_interp_congo_025.npy")
rain = np.load(mydir+"rain_interp_congo_025.npy")
pres = np.load(mydir+"pressure_interp_congo_025.npy")
radi = np.load(mydir+"radiation_interp_congo_025.npy")
lon = np.load(mydir+"gedi_lon_congo_025.npy")
lat = np.load(mydir+"gedi_lat_congo_025.npy")
y = np.load(mydir+"gedi_agbd_congo_025.npy")

alldata = np.concatenate((lat.reshape(-1,1),lon.reshape(-1,1),lai.reshape(-1,1),\
                    wind.reshape(-1,1),temp.reshape(-1,1),rain.reshape(-1,1),\
                    pres.reshape(-1,1),radi.reshape(-1,1),y.reshape(-1,1)),axis=1)
alldata = alldata[~np.isnan(alldata).any(axis=1)] # remove nan

# %% [markdown]
# only run if you need to save alldata for hyperparameter tuning

# %%
alldata = pd.DataFrame(alldata, columns=col_names)
print(alldata.shape)
pd.DataFrame(alldata).to_csv(datadir+'all_data.csv',index=False)

# %%
X = alldata[:,:-1] # split into X
y = alldata[:,-1] # split into y

sc_X = MinMaxScaler(feature_range=(0,1))
sc_y = MinMaxScaler(feature_range=(0,1))

fitted_X_scaled = sc_X.fit_transform(X)
fitted_y_scaled = sc_y.fit_transform(y.reshape(-1,1))

# stratified random sampling
n_strata = 20 # cover 0-99% percentiles, the rest is assigned to the last strata bin
strata_bins = np.full([n_strata],np.nan)
for j in range(n_strata):
    strata_bins[j] = np.percentile(fitted_y_scaled,99/n_strata*(j+1))
strata_y = np.full([len(fitted_y_scaled),1],0)
for j in range(len(fitted_y_scaled)):
    if fitted_y_scaled[j] <= strata_bins[0]:
        strata_y[j] = 1
    elif fitted_y_scaled[j] <= strata_bins[n_strata-1]:
        for k in range(n_strata-1):
            if fitted_y_scaled[j] <= strata_bins[k+1] and fitted_y_scaled[j] > strata_bins[k]:
                strata_y[j] = k+1
    else:
        strata_y[j] = n_strata-1

X_train,X_test,y_train,y_test = train_test_split(fitted_X_scaled,fitted_y_scaled,test_size=0.2,stratify=strata_y,random_state=0)

# %%
# Build model
layers = [8, 25, 15, 20, 24, 19, 1]
I = layers[0]
J = layers[-1]
nodes = layers[1:-1]
input_part1 = Input(shape=(I,))
ann_part1 = Dense(units=nodes[0], activation='relu')(input_part1)
ann_part1 = Dense(units=nodes[1], activation='relu')(ann_part1)
ann_part1 = Dense(units=nodes[2], activation='relu')(ann_part1)
ann_part1 = Dense(units=nodes[3], activation='relu')(ann_part1)
ann_part1 = Dense(units=nodes[4], activation='relu')(ann_part1)
ann_out = Dense(units=1, activation='linear')(ann_part1)
model = tf.keras.Model(inputs=input_part1, outputs=ann_out)
model.summary()

myepochs = 1000
mybatch_size = 10

#change
opt = tf.keras.optimizers.RMSprop(learning_rate=0.000086988854789057)
model.compile(optimizer = opt,loss = 'mse')
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 8)]               0
#
#  dense_6 (Dense)             (None, 25)                225
#
#  dense_7 (Dense)             (None, 15)                390
#
#  dense_8 (Dense)             (None, 20)                320
#
#  dense_9 (Dense)             (None, 24)                504
#
#  dense_10 (Dense)            (None, 19)                475
#
#  dense_11 (Dense)            (None, 1)                 20
#
# =================================================================
# Total params: 1934 (7.55 KB)
# Trainable params: 1934 (7.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train,y_train,\
              batch_size=mybatch_size,epochs=myepochs,\
              validation_data=(X_test,y_test))

model.save('congo_ann_initial.keras')
np.save('ann_initial_congo_history.npy',history.history)
# Out:
# Epoch 1/1000
# 202/202 [==============================] - 1s 2ms/step - loss: 0.0255 - val_loss: 0.0200
# Epoch 2/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0190 - val_loss: 0.0195
# Epoch 3/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0186 - val_loss: 0.0192
# Epoch 4/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0182 - val_loss: 0.0188
# Epoch 5/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0179 - val_loss: 0.0186
# Epoch 6/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0176 - val_loss: 0.0183
# Epoch 7/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0173 - val_loss: 0.0181
# Epoch 8/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0170 - val_loss: 0.0179
# Epoch 9/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0168 - val_loss: 0.0177
# Epoch 10/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0166 - val_loss: 0.0175
# Epoch 11/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0164 - val_loss: 0.0174
# Epoch 12/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0163 - val_loss: 0.0172
# Epoch 13/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0161 - val_loss: 0.0171
# Epoch 14/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0160 - val_loss: 0.0169
# Epoch 15/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0159 - val_loss: 0.0169
# Epoch 16/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0157 - val_loss: 0.0167
# Epoch 17/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0156 - val_loss: 0.0165
# Epoch 18/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0155 - val_loss: 0.0164
# Epoch 19/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0154 - val_loss: 0.0163
# Epoch 20/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0153 - val_loss: 0.0163
# Epoch 21/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0152 - val_loss: 0.0162
# Epoch 22/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0152 - val_loss: 0.0160
# Epoch 23/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0151 - val_loss: 0.0160
# Epoch 24/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0150 - val_loss: 0.0159
# Epoch 25/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0150 - val_loss: 0.0158
# Epoch 26/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0149 - val_loss: 0.0157
# Epoch 27/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0157
# Epoch 28/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0148 - val_loss: 0.0156
# Epoch 29/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0147 - val_loss: 0.0155
# Epoch 30/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0147 - val_loss: 0.0154
# Epoch 31/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0146 - val_loss: 0.0155
# Epoch 32/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0146 - val_loss: 0.0154
# Epoch 33/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0145 - val_loss: 0.0153
# Epoch 34/1000
# 202/202 [==============================] - 1s 3ms/step - loss: 0.0145 - val_loss: 0.0153
# Epoch 35/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0144 - val_loss: 0.0152
# Epoch 36/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0144 - val_loss: 0.0152
# Epoch 37/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0143 - val_loss: 0.0151
# Epoch 38/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0152
# Epoch 39/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0152
# Epoch 40/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0143 - val_loss: 0.0150
# Epoch 41/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0153
# Epoch 42/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0150
# Epoch 43/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0149
# Epoch 44/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0142 - val_loss: 0.0150
# Epoch 45/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0149
# Epoch 46/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0149
# Epoch 47/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0141 - val_loss: 0.0148
# Epoch 48/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0141 - val_loss: 0.0148
# Epoch 49/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0140 - val_loss: 0.0148
# Epoch 50/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0140 - val_loss: 0.0148
# Epoch 51/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0140 - val_loss: 0.0148
# Epoch 52/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0140 - val_loss: 0.0149
# Epoch 53/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0147
# Epoch 54/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0140 - val_loss: 0.0147
# Epoch 55/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0148
# Epoch 56/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0148
# Epoch 57/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0147
# Epoch 58/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0147
# Epoch 59/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0147
# Epoch 60/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0146
# Epoch 61/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0138 - val_loss: 0.0146
# Epoch 62/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0138 - val_loss: 0.0147
# Epoch 63/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0146
# Epoch 64/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0138 - val_loss: 0.0145
# Epoch 65/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0145
# Epoch 66/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0138 - val_loss: 0.0147
# Epoch 67/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0145
# Epoch 68/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0138 - val_loss: 0.0145
# Epoch 69/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0145
# Epoch 70/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0146
# Epoch 71/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0145
# Epoch 72/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0137 - val_loss: 0.0144
# Epoch 73/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 74/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0146
# Epoch 75/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0145
# Epoch 76/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 77/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 78/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 79/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 80/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 81/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0147
# Epoch 82/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 83/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0145
# Epoch 84/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0135 - val_loss: 0.0143
# Epoch 85/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0135 - val_loss: 0.0144
# Epoch 86/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0135 - val_loss: 0.0144
# Epoch 87/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0143
# Epoch 88/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0135 - val_loss: 0.0143
# Epoch 89/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0135 - val_loss: 0.0143
# Epoch 90/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0145
# Epoch 91/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0135 - val_loss: 0.0144
# Epoch 92/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0145
# Epoch 93/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0143
# Epoch 94/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0135 - val_loss: 0.0144
# Epoch 95/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0143
# Epoch 96/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 97/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 98/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0134 - val_loss: 0.0143
# Epoch 99/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0143
# Epoch 100/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 101/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 102/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 103/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0143
# Epoch 104/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 105/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0142
# Epoch 106/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0142
# Epoch 107/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 108/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0143
# Epoch 109/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 110/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0143
# Epoch 111/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0142
# Epoch 112/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 113/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 114/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 115/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 116/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 117/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 118/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 119/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0141
# Epoch 120/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 121/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0143
# Epoch 122/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 123/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 124/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0140
# Epoch 125/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 126/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0143
# Epoch 127/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0140
# Epoch 128/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0140
# Epoch 129/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0140
# Epoch 130/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0140
# Epoch 131/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0144
# Epoch 132/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 133/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0140
# Epoch 134/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0141
# Epoch 135/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 136/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 137/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0140
# Epoch 138/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0139
# Epoch 139/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0141
# Epoch 140/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 141/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 142/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 143/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 144/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 145/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0131 - val_loss: 0.0142
# Epoch 146/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0139
# Epoch 147/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 148/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0141
# Epoch 149/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0143
# Epoch 150/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 151/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0140
# Epoch 152/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0141
# Epoch 153/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0140
# Epoch 154/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0139
# Epoch 155/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0131 - val_loss: 0.0139
# Epoch 156/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 157/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0138
# Epoch 158/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0140
# Epoch 159/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0140
# Epoch 160/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 161/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0142
# Epoch 162/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 163/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0144
# Epoch 164/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 165/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0130 - val_loss: 0.0140
# Epoch 166/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0141
# Epoch 167/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 168/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0138
# Epoch 169/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 170/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 171/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 172/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 173/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0138
# Epoch 174/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0138
# Epoch 175/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 176/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 177/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 178/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0140
# Epoch 179/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 180/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0130 - val_loss: 0.0139
# Epoch 181/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0140
# Epoch 182/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0139
# Epoch 183/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0139
# Epoch 184/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0141
# Epoch 185/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0140
# Epoch 186/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0139
# Epoch 187/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0139
# Epoch 188/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 189/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 190/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0139
# Epoch 191/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0139
# Epoch 192/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 193/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 194/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 195/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0139
# Epoch 196/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 197/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 198/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 199/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 200/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 201/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 202/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0137
# Epoch 203/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 204/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 205/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 206/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 207/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0142
# Epoch 208/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 209/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0140
# Epoch 210/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 211/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0143
# Epoch 212/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0138
# Epoch 213/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 214/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 215/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 216/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 217/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0140
# Epoch 218/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0137
# Epoch 219/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0129 - val_loss: 0.0137
# Epoch 220/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 221/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 222/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0138
# Epoch 223/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 224/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 225/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0139
# Epoch 226/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0140
# Epoch 227/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 228/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0139
# Epoch 229/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0140
# Epoch 230/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0137
# Epoch 231/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 232/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 233/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0128 - val_loss: 0.0137
# Epoch 234/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0138
# Epoch 235/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 236/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 237/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0138
# Epoch 238/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0137
# Epoch 239/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0137
# Epoch 240/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0138
# Epoch 241/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0136
# Epoch 242/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0140
# Epoch 243/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0137
# Epoch 244/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 245/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 246/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0144
# Epoch 247/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0139
# Epoch 248/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 249/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0140
# Epoch 250/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 251/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 252/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0138
# Epoch 253/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0140
# Epoch 254/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0139
# Epoch 255/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 256/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0140
# Epoch 257/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0138
# Epoch 258/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0139
# Epoch 259/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0140
# Epoch 260/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 261/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 262/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 263/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 264/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 265/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 266/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0138
# Epoch 267/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 268/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 269/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0137
# Epoch 270/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 271/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 272/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 273/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0135
# Epoch 274/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 275/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 276/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0135
# Epoch 277/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 278/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 279/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0138
# Epoch 280/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0138
# Epoch 281/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 282/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 283/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 284/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 285/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 286/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 287/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 288/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 289/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 290/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 291/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0138
# Epoch 292/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 293/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0139
# Epoch 294/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0139
# Epoch 295/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0136
# Epoch 296/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 297/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 298/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 299/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0142
# Epoch 300/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 301/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 302/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0135
# Epoch 303/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0135
# Epoch 304/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0140
# Epoch 305/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 306/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 307/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 308/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0135
# Epoch 309/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 310/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0138
# Epoch 311/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 312/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 313/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0138
# Epoch 314/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 315/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 316/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 317/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 318/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 319/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 320/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 321/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 322/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 323/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0135
# Epoch 324/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 325/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0141
# Epoch 326/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 327/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0136
# Epoch 328/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0138
# Epoch 329/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0137
# Epoch 330/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 331/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 332/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0126 - val_loss: 0.0138
# Epoch 333/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 334/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0138
# Epoch 335/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 336/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 337/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 338/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0138
# Epoch 339/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 340/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 341/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 342/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 343/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0138
# Epoch 344/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 345/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 346/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0138
# Epoch 347/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 348/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 349/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 350/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 351/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0138
# Epoch 352/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 353/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 354/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 355/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 356/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 357/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 358/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 359/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 360/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 361/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0146
# Epoch 362/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 363/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 364/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 365/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0138
# Epoch 366/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 367/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 368/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 369/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 370/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 371/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 372/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 373/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0141
# Epoch 374/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0139
# Epoch 375/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 376/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 377/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 378/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 379/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 380/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 381/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0137
# Epoch 382/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 383/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 384/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0142
# Epoch 385/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 386/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 387/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0136
# Epoch 388/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 389/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 390/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 391/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0125 - val_loss: 0.0135
# Epoch 392/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 393/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 394/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 395/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 396/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 397/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 398/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 399/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0138
# Epoch 400/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 401/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0138
# Epoch 402/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 403/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 404/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 405/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 406/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0134
# Epoch 407/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0138
# Epoch 408/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 409/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 410/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 411/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 412/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 413/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 414/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 415/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0138
# Epoch 416/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 417/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 418/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 419/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 420/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 421/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0134
# Epoch 422/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 423/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0136
# Epoch 424/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0139
# Epoch 425/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 426/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 427/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0136
# Epoch 428/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 429/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0138
# Epoch 430/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 431/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0138
# Epoch 432/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 433/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 434/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 435/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0139
# Epoch 436/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0138
# Epoch 437/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 438/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0136
# Epoch 439/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 440/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0136
# Epoch 441/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0141
# Epoch 442/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0135
# Epoch 443/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0137
# Epoch 444/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0136
# Epoch 445/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 446/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0135
# Epoch 447/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0135
# Epoch 448/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0124 - val_loss: 0.0136
# Epoch 449/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0135
# Epoch 450/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0138
# Epoch 451/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 452/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 453/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 454/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 455/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0136
# Epoch 456/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0135
# Epoch 457/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0136
# Epoch 458/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 459/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0135
# Epoch 460/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0136
# Epoch 461/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0139
# Epoch 462/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0123 - val_loss: 0.0137
# Epoch 463/1000
# ...
# Epoch 851/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0134
# Epoch 852/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 853/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 854/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0132
# Epoch 855/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0135
# Epoch 856/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0135
# Epoch 857/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0140
# Epoch 858/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0138
# Epoch 859/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0136
# Epoch 860/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 861/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0132
# Epoch 862/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0134
# Epoch 863/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0116 - val_loss: 0.0135
# Epoch 864/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0136
# Epoch 865/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0134
# Epoch 866/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 867/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 868/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0134
# Epoch 869/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0134
# Epoch 870/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0139
# Epoch 871/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0132
# Epoch 872/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 873/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 874/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 875/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0134
# Epoch 876/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0142
# Epoch 877/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0136
# Epoch 878/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 879/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0134
# Epoch 880/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0132
# Epoch 881/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0136
# Epoch 882/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 883/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0138
# Epoch 884/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0116 - val_loss: 0.0136
# Epoch 885/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0141
# Epoch 886/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 887/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0134
# Epoch 888/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 889/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 890/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 891/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0132
# Epoch 892/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0138
# Epoch 893/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 894/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0134
# Epoch 895/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 896/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 897/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 898/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0137
# Epoch 899/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 900/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0139
# Epoch 901/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0132
# Epoch 902/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0136
# Epoch 903/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 904/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0136
# Epoch 905/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0147
# Epoch 906/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0140
# Epoch 907/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0136
# Epoch 908/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 909/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 910/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0139
# Epoch 911/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0138
# Epoch 912/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0116 - val_loss: 0.0134
# Epoch 913/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0140
# Epoch 914/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 915/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0135
# Epoch 916/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 917/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 918/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0140
# Epoch 919/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 920/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 921/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0136
# Epoch 922/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 923/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 924/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 925/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 926/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0138
# Epoch 927/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 928/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0132
# Epoch 929/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0115 - val_loss: 0.0134
# Epoch 930/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 931/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 932/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0138
# Epoch 933/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 934/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 935/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 936/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0140
# Epoch 937/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0132
# Epoch 938/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 939/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0115 - val_loss: 0.0133
# Epoch 940/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0137
# Epoch 941/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 942/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 943/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0141
# Epoch 944/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 945/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 946/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0132
# Epoch 947/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 948/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0139
# Epoch 949/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0137
# Epoch 950/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 951/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0141
# Epoch 952/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 953/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0142
# Epoch 954/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 955/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 956/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0135
# Epoch 957/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0136
# Epoch 958/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0132
# Epoch 959/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 960/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 961/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 962/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 963/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 964/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0134
# Epoch 965/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0137
# Epoch 966/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 967/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0136
# Epoch 968/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0132
# Epoch 969/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0133
# Epoch 970/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0138
# Epoch 971/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0138
# Epoch 972/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0135
# Epoch 973/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0136
# Epoch 974/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0137
# Epoch 975/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0133
# Epoch 976/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0137
# Epoch 977/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0136
# Epoch 978/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 979/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0134
# Epoch 980/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0138
# Epoch 981/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0136
# Epoch 982/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0139
# Epoch 983/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0133
# Epoch 984/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0135
# Epoch 985/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0134
# Epoch 986/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0139
# Epoch 987/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0136
# Epoch 988/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 989/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 990/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0138
# Epoch 991/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 992/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0135
# Epoch 993/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0134
# Epoch 994/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 995/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0141
# Epoch 996/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0139
# Epoch 997/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0113 - val_loss: 0.0137
# Epoch 998/1000
# 202/202 [==============================] - 0s 2ms/step - loss: 0.0114 - val_loss: 0.0134
# Epoch 999/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0133
# Epoch 1000/1000
# 202/202 [==============================] - 0s 1ms/step - loss: 0.0113 - val_loss: 0.0139
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from matplotlib.pyplot import figure

#visualize
y_pred = model.predict(X_train)

# Calculate the point density
xy = np.vstack((y_pred.reshape(-1,),y_train.reshape(-1,)))
color = gaussian_kde(xy)(xy)
#train
figure(figsize=(3,3), dpi=300)
plt.scatter(y_pred,y_train,label='Train',c=color,s=2,cmap='plasma')
plt.plot(range(0,2),range(0,2))
plt.xlim(0,1)
plt.ylim(0,1)
#plt.legend()
plt.show()

#test
y_pred = model.predict(X_test)
# Calculate the point density
xy = np.vstack((y_pred.reshape(-1,),y_test.reshape(-1,)))
color = gaussian_kde(xy)(xy)
#test
figure(figsize=(3,3), dpi=300)
plt.scatter(y_pred,y_test,label='Test',c=color,s=2,cmap='plasma')
plt.plot(range(0,2),range(0,2))
plt.xlim(0,1)
plt.ylim(0,1)
#plt.legend()
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.ylim(0.01,0.024)
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

print(r2_score(y_train,model.predict(X_train)))
print(r2_score(y_test,model.predict(X_test)))
# Out:
# 63/63 [==============================] - 0s 851us/step
# 16/16 [==============================] - 0s 1ms/step
# 63/63 [==============================] - 0s 701us/step
# 0.3896379404308351
# 16/16 [==============================] - 0s 701us/step
# 0.317257158660463

# %%
amazondir = '../amazonCodes/alldata/'
#load amazon data
lai_a = np.load(amazondir+"lai_hv_interp_025.npy")
wind_a = np.load(amazondir+"wind_interp_025.npy")
temp_a = np.load(amazondir+"temperature_interp_025.npy")
rain_a = np.load(amazondir+"rain_interp_025.npy")
pres_a = np.load(amazondir+"pressure_interp_025.npy")
radi_a = np.load(amazondir+"radiation_interp_025.npy")
lon_a = np.load(amazondir+"gedi_lon_025.npy")
lat_a = np.load(amazondir+"gedi_lat_025.npy")
y_a = np.load(amazondir+"gedi_agbd_025.npy")

alldata2 = np.concatenate((lat_a.reshape(-1,1),lon_a.reshape(-1,1),lai_a.reshape(-1,1),\
                    wind_a.reshape(-1,1),temp_a.reshape(-1,1),rain_a.reshape(-1,1),\
                    pres_a.reshape(-1,1),radi_a.reshape(-1,1),y_a.reshape(-1,1)),axis=1)
alldata2 = alldata2[~np.isnan(alldata2).any(axis=1)] # remove nan

# %% [markdown]
# DON'T RUN UNLESS YOU NEED TO SAVE ALLDATA2

# %%
alldata2 = pd.DataFrame(alldata2, columns=col_names)
print(alldata2.shape)
pd.DataFrame(alldata2).to_csv(mydir+'all_data.csv',index=False)

# %%
np.save(amazondir+'alldata2.npy',alldata2)

# %%
plt.scatter(alldata2[:,1],alldata2[:,0],cmap='viridis',c=alldata2[:,8],s=1)
plt.plot()
# Out:
# []

# %% [markdown]
# Trial 9 finished with value: 0.01986623350530863 and parameters: {'n_layers': 9, 'activation': 'sigmoid', 'out_activation': 'relu', 'n_units_l0': 13, 'n_units_l1': 11, 'n_units_l2': 12, 'n_units_l3': 6, 'n_units_l4': 6, 'n_units_l5': 11, 'n_units_l6': 11, 'n_units_l7': 6, 'n_units_l8': 11, 'optimizer': 'SGD', 'SGD_learning_rate': 0.0001949024356366169}. Best is trial 4 with value: 0.014281144738197327.
#
# Trial 40 finished with value: 0.014607313834130765 and parameters: {'n_layers': 9, 'activation': 'relu', 'out_activation': 'relu', 'n_units_l0': 13, 'n_units_l1': 9, 'n_units_l2': 9, 'n_units_l3': 14, 'n_units_l4': 13, 'n_units_l5': 13, 'n_units_l6': 12, 'n_units_l7': 11, 'n_units_l8': 9, 'optimizer': 'RMSprop', 'RMSprop_learning_rate': 0.0003769103165284093}. Best is trial 33 with value: 0.013559369742870331.

# %%
X = alldata2[:,:-1] # split into X
y = alldata2[:,-1] # split into y

fitted_X_scaled = sc_X.transform(X)
fitted_y_scaled = sc_y.transform(y.reshape(-1,1))

# stratified random sampling
n_strata = 20 # cover 0-99% percentiles, the rest is assigned to the last strata bin
strata_bins = np.full([n_strata],np.nan)
for j in range(n_strata):
    strata_bins[j] = np.percentile(fitted_y_scaled,99/n_strata*(j+1))
strata_y = np.full([len(fitted_y_scaled),1],0)
for j in range(len(fitted_y_scaled)):
    if fitted_y_scaled[j] <= strata_bins[0]:
        strata_y[j] = 1
    elif fitted_y_scaled[j] <= strata_bins[n_strata-1]:
        for k in range(n_strata-1):
            if fitted_y_scaled[j] <= strata_bins[k+1] and fitted_y_scaled[j] > strata_bins[k]:
                strata_y[j] = k+1
    else:
        strata_y[j] = n_strata-1

X_train,X_test,y_train,y_test = train_test_split(fitted_X_scaled,fitted_y_scaled,test_size=0.2,stratify=strata_y,random_state=0)

# %% [markdown]
# Glorious K

# %%
k=5

# %%
model = load_model('congo_ann_initial.keras')

layers = len(model.layers)

#set all but the last 3 layers as untrainable
for i in range (k):
    model.layers[i].trainable = False
    
#model.compile(optimizer = opt,loss = 'mse')

history_amazon = model.fit(X_train,y_train,\
              batch_size=mybatch_size,epochs=myepochs,\
              validation_data=(X_test,y_test))
#save
np.save('ann_transfer_history_k_'+str(k)+'.npy',history_amazon.history)
#history_amazon=np.load('ann_transfer_history_k_.npy',allow_pickle='TRUE').item()
model.save('congo_ann_k_'+str(k)+'.keras')
# Out:
# Epoch 1/1000
# 1017/1017 [==============================] - 2s 1ms/step - loss: 0.0240 - val_loss: 0.0186
# Epoch 2/1000
# 1017/1017 [==============================] - 1s 1ms/step - loss: 0.0142 - val_loss: 0.0152
# Epoch 3/1000
# 1017/1017 [==============================] - 2s 2ms/step - loss: 0.0137 - val_loss: 0.0154
# Epoch 4/1000
#  783/1017 [======================>.......] - ETA: 0s - loss: 0.0135
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[215], line 11
#       7     model.layers[i].trainable = False
#       9 #model.compile(optimizer = opt,loss = 'mse')
# ---> 11 history_amazon = model.fit(X_train,y_train,\
#      12               batch_size=mybatch_size,epochs=myepochs,\
#      13               validation_data=(X_test,y_test))
#      14 #save
#      15 np.save('ann_transfer_history_k_'+str(k)+'.npy',history_amazon.history)
#
# File c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\keras\src\engine\training.py:1798, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1796 callbacks.on_epoch_begin(epoch)
#    1797 with data_handler.catch_stop_iteration():
# -> 1798     for step in data_handler.steps():
#    1799         with tf.profiler.experimental.Trace(
#    1800             "train",
#    1801             epoch_num=epoch,
#    (...)
#    1804             _r=1,
#    1805         ):
#    1806             callbacks.on_train_batch_begin(step)
#
# File c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\keras\src\engine\data_adapter.py:1411, in DataHandler.steps(self)
#    1409 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1410     break
# -> 1411 original_spe = self._steps_per_execution.numpy().item()
#    1412 can_run_full_execution = (
#    1413     original_spe == 1
#    1414     or self._inferred_steps is None
#    1415     or self._inferred_steps - self._current_step >= original_spe
#    1416 )
#    1418 if can_run_full_execution:
#
# File c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:689, in BaseResourceVariable.numpy(self)
#     687 def numpy(self):
#     688   if context.executing_eagerly():
# --> 689     return self.read_value().numpy()
#     690   raise NotImplementedError(
#     691       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:839, in BaseResourceVariable.read_value(self)
#     830 """Constructs an op which reads the value of this variable.
#     831
#     832 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     836   The value of the variable.
#     837 """
#     838 with ops.name_scope("Read"):
# --> 839   value = self._read_variable_op()
#     840 # Return an identity so it can get placed on whatever device the context
#     841 # specifies instead of the device where the variable is.
#     842 return array_ops.identity(value)
#
# File c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:818, in BaseResourceVariable._read_variable_op(self, no_copy)
#     816       result = read_and_set_handle(no_copy)
#     817 else:
# --> 818   result = read_and_set_handle(no_copy)
#     820 if not context.executing_eagerly():
#     821   # Note that if a control flow context is active the input of the read op
#     822   # might not actually be the handle. This line bypasses it.
#     823   record.record_operation(
#     824       "ReadVariableOp", [result], [self.handle],
#     825       backward_function=lambda x: [x],
#     826       forward_function=lambda x: [x])
#
# File c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:808, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     806 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     807   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 808 result = gen_resource_variable_ops.read_variable_op(
#     809     self.handle, self._dtype)
#     810 _maybe_set_handle_data(self._dtype, self.handle, result)
#     811 return result
#
# File c:\Users\haofg\anaconda3\envs\remotesensing2\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:535, in read_variable_op(resource, dtype, name)
#     533 if tld.is_eager:
#     534   try:
# --> 535     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     536       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     537     return _result
#     538   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# Save tranfered model **BE SURE TO CHANGE k**

# %%
model.save('congo_ann_k_'+str(k)+'.keras')

# %% [markdown]
# remember to change k

# %%
for k in range (1,5):
    history = np.load('ann_transfer_history_k_'+str(k)+'.npy', allow_pickle=True)
    plt.plot(history.item()['loss'])
    plt.plot(history.item()['val_loss'])
    plt.ylabel('loss (mse)')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.ylim(0.01,0.025)
    plt.show()
history = np.load('ann_transfer_history_k_'+str(k)+'.npy', allow_pickle=True)
    plt.plot(history.item()['loss'])
    plt.plot(history.item()['val_loss'])
    plt.ylabel('loss (mse)')
    plt.xlabel('epoch')
    plt.legend(['train', 'validation'], loc='upper right')
    plt.ylim(0.01,0.025)
    plt.show()

# %%
model = load_model('congo_ann_initial.keras')#'congo_ann_k_'+str(k)+'.keras')
#visualize
y_pred = model.predict(X_train)

# Calculate the point density
xy = np.vstack((y_pred.reshape(-1,),y_train.reshape(-1,)))
color = gaussian_kde(xy)(xy)
#train
figure(figsize=(3,3), dpi=300)
plt.xlim(0,1)
plt.ylim(0,1)
plt.scatter(y_pred,y_train,label='Train',c=color,s=2,cmap='inferno')
plt.plot(range(0,2),range(0,2))
plt.legend()
plt.show()

#test
y_pred = model.predict(X_test)
# Calculate the point density
xy = np.vstack((y_pred.reshape(-1,),y_test.reshape(-1,)))
color = gaussian_kde(xy)(xy)
#test
figure(figsize=(3,3), dpi=300)
plt.xlim(0,1)
plt.ylim(0,1)
plt.scatter(y_pred,y_test,label='Test',c=color,s=2,cmap='inferno')
plt.plot(range(0,2),range(0,2))
plt.legend()
plt.show()

history = np.load('ann_transfer_history_k_'+str(k)+'.npy')

plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.ylim(0.01,0.025)
plt.show()

print(r2_score(y_train,model.predict(X_train)))
print(r2_score(y_test,model.predict(X_test)))
# Out:
# 318/318 [==============================] - 0s 765us/step
# 80/80 [==============================] - 0s 1ms/step
# 318/318 [==============================] - 0s 946us/step
# -36.26535693482356
# 80/80 [==============================] - 0s 567us/step
# -34.01505838515013

# %%
print(sum(y_a < 0))
print(color)
print(alldata2.shape[0])
# Out:
# 0
# [ 7.66341651 20.41224593  8.35940209 ... 11.67753242 50.98874094
#  56.83045922]
# 12711

# %% [markdown]
# map biomass

# %%
print(data_nc.files)
# Out:
# ['lai_hv', 'temperature', 'rain', 'radiation', 'pressure', 'wind']

# %%
import numpy.ma as ma
from scipy.interpolate import griddata

#lon
xmin = -80
xmax = -43
#lat
ymin = -20
ymax = 10
#(lon,lat)

X = np.arange(xmin, xmax+0.1, 0.1) # replace with ERA5 longitude
Y = np.arange(ymin, ymax+0.1, 0.1) # replace with ERA5 latitude
grid=[]
for i in range(len(X)):
    for j in range(len(Y)):
        grid.append([X[i], Y[j]])
grid = np.array(grid)

X = np.arange(xmin, xmax+0.25, 0.25) # replace with ERA5 longitude
Y = np.arange(ymin, ymax+0.25, 0.25) # replace with ERA5 latitude
grid_new=[]
for i in range(len(X)):
    for j in range(len(Y)):
        grid_new.append([X[i], Y[j]])
grid_new = np.array(grid_new)

amazondir = '../amazonCodes/'
data_nc = np.load(amazondir+'nctimeavg.npz')
mask = np.load(amazondir+'nctimeavg_ma.npz')

#X = np.concatenate((grid_new[:,1].reshape(-1,1), grid_new[:,0].reshape(-1,1)), axis=1)
for varname, varmask in zip(data_nc.files, mask.files):
    #reconstrtuct masked array
    temp = ma.array(data_nc[varname], mask = mask[varmask])
    temp = ma.filled(temp, fill_value = np.nan) 
    values=[]
    for i in range(len(grid)):
        #if np.isnan(temp[900 - int(grid[i,1] * 10)][(3600 + int(grid[i,0] * 10)) % 3600]):
         #   values.append(0)
        #else:
        values.append(temp[900 - int(grid[i,1] * 10)][(3600 + int(grid[i,0] * 10)) % 3600]) 
    data_new = griddata(grid, values, grid_new, method='nearest') 
    if varname == 'lai_hv':
        lai = data_new
    if varname == 'temperature':
        tempe = data_new
    if varname == 'wind':
        wind = data_new
    if varname == 'radiation':
        radi = data_new
    if varname == 'pressure':
        pres = data_new
    if varname == 'rain':
        rain = data_new
X = np.concatenate((grid_new[:,1].reshape(-1,1), grid_new[:,0].reshape(-1,1),lai.reshape(-1,1)\
                    ,wind.reshape(-1,1),tempe.reshape(-1,1),rain.reshape(-1,1),\
                    pres.reshape(-1,1),radi.reshape(-1,1)),axis=1)
X = X[~np.isnan(X).any(axis=1)] # remove nan
print(sum(~np.isnan(X)))

for k in range(1,5):
    model = load_model('congo_ann_k_'+str(k)+'.keras')
    fitted_X_scaled = sc_X.transform(X)
    y_pred = model.predict(fitted_X_scaled)
    y_est = sc_y.inverse_transform(y_pred.reshape(-1,1))
    y_est[y_pred <= 0] = 0
    #convert from density to biomass in Mg
    y_est = y_est * 75625
    plt.scatter(X[:,1], X[:,0], c=y_est, s=3, cmap='viridis', marker='s', vmax = 2.25e7)
    plt.colorbar()
    plt.ylim(ymin,ymax)
    plt.xlim(xmin,xmax)
    plt.show()
    print(sum(y_est))
# Out:
# [14637 14637 14637 14637 14637 14637 14637 14637]
# 458/458 [==============================] - 1s 1ms/step
# WARNING:absl:Skipping variable loading for optimizer 'RMSprop', because it has 11 variables whereas the saved optimizer has 13 variables.
# [1.3856362e+11]
# 458/458 [==============================] - 1s 1ms/step
# WARNING:absl:Skipping variable loading for optimizer 'RMSprop', because it has 9 variables whereas the saved optimizer has 13 variables.
# [1.18756109e+11]
# 458/458 [==============================] - 1s 1ms/step
# [1.34272039e+11]
# 458/458 [==============================] - 1s 1ms/step
# [1.57029186e+11]
